# %%
import pickle

# %%
loaded_model=pickle.load(open("finalised_model_Random_forest.sav",'rb'))
result=loaded_model.predict([[1233,123134,1232,0,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([53219.8282])
